# %% [markdown]
# <a href="https://colab.research.google.com/github/tagakj/CL2025HSE/blob/main/1_%D0%9F%D1%80%D0%B5%D0%B4%D0%BE%D0%B1%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%BA%D0%B0_CL_%D0%A2%D0%B0%D1%82%D1%8C%D1%8F%D0%BD%D0%B0%20%D0%93%D0%B0%D0%B2%D1%80%D0%B8%D0%BB%D0%BE%D0%B2%D0%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Домашнее задание: Предварительная обработка текстовых данных**

# %% [markdown]
# Здесь вам предстоит закрепить навыки нормализации текста, работы с регулярными выражениями, токенизации и удаления стоп-слов. Вы будете работать с первыми двумя главами Мцыри М.Ю. Лермонтова и выполнять различные этапы его предварительной обработки.

# %%
text = """

Немного лет тому назад,
Там, где, сливаяся, шумят,
Обнявшись, будто две сестры,
Струи Арагвы и Куры,
Был монастырь. Из-за горы
И нынче видит пешеход
Столбы обрушенных ворот,
И башни, и церковный свод;
Но не курится уж под ним
Кадильниц благовонный дым,
Не слышно пенье в поздний час
Молящих иноков за нас.
Теперь один старик седой,
Развалин страж полуживой,
Людьми и смертию забыт,
Сметает пыль с могильных плит,
Которых надпись говорит
О славе прошлой — и о том,
Как, удручен своим венцом,
Такой-то царь, в такой-то год,
Вручал России свой народ.
И божья благодать сошла
На Грузию! Она цвела
С тех пор в тени своих садов,
Не опасаяся врагов,
3а гранью дружеских штыков.

Однажды русский генерал
Из гор к Тифлису проезжал;
Ребенка пленного он вез.
Тот занемог, не перенес
Трудов далекого пути;
Он был, казалось, лет шести,
Как серна гор, пуглив и дик
И слаб и гибок, как тростник.
Но в нем мучительный недуг
Развил тогда могучий дух
Его отцов. Без жалоб он
Томился, даже слабый стон
Из детских губ не вылетал,
Он знаком пищу отвергал
И тихо, гордо умирал.
Из жалости один монах
Больного призрел, и в стенах
Хранительных остался он,
Искусством дружеским спасен.
Но, чужд ребяческих утех,
Сначала бегал он от всех,
Бродил безмолвен, одинок,
Смотрел, вздыхая, на восток,
Гоним неясною тоской
По стороне своей родной.
Но после к плену он привык,
Стал понимать чужой язык,
Был окрещен святым отцом
И, с шумным светом незнаком,
Уже хотел во цвете лет
Изречь монашеский обет,
Как вдруг однажды он исчез
Осенней ночью. Темный лес
Тянулся по горам кругом.
Три дня все поиски по нем
Напрасны были, но потом
Его в степи без чувств нашли
И вновь в обитель принесли.
Он страшно бледен был и худ
И слаб, как будто долгий труд,
Болезнь иль голод испытал.
Он на допрос не отвечал
И с каждым днем приметно вял.
И близок стал его конец;
Тогда пришел к нему чернец
С увещеваньем и мольбой;
И, гордо выслушав, больной
Привстал, собрав остаток сил,
И долго так он говорил:

"""

# %% [markdown]
# Задание 1: Регулярные выражения
#
# 1.    Напишите регулярное выражение, которое найдет все слова, которые начинаются с сочетания букв "**ста**".
#
# 2.    Напишите регулярное выражение, которое найдет все слова с сочетанием букв **ста** как в начале, так и внутри слов.
#
# 3. Модернизируйте это выражение так, чтобы буква **т** была опциональной (вместо нее может быть любой другой символ).
#
#
#
# *Не забывайте импортировать нужные библиотеки*

# %%
# 1) регулярное выражение, которое найдет все слова, которые начинаются с сочетания букв "ста"
import re
print(re.findall(r'\b[Сс]та\w*', text))
# Out:
# ['старик', 'Стал', 'стал']

# %%
# 2) регулярное выражение, которое найдет все слова с сочетанием букв ста как в начале, так и внутри слов
print(re.findall(r'\w*[Сс]та\w*', text))
# Out:
# ['старик', 'остался', 'Стал', 'стал', 'Привстал', 'остаток']

# %%
# 3) чтобы буква т была опциональной (вместо нее может быть любой другой символ)
print(re.findall(r'\w*[Сс][а-я]а\w*', text))
# Out:
# ['старик', 'славе', 'слаб', 'слабый', 'остался', 'спасен', 'Сначала', 'Стал', 'слаб', 'стал', 'Привстал', 'остаток']

# %% [markdown]
# Задание 2: Нормализация текста
#
# 1.   Преобразуйте текст из переменной text к нижнему регистру.
#
# 2.   Удалите все символы пунктуации и переноса строки (\n), используя регулярные выражения.

# %%
# 1) приводим к нижнему регистру
lower_text = text.lower()
print(lower_text)
# Out:
# немного лет тому назад,
# там, где, сливаяся, шумят,
# обнявшись, будто две сестры,
# струи арагвы и куры,
# был монастырь. из-за горы
# и нынче видит пешеход
# столбы обрушенных ворот,
# и башни, и церковный свод;
# но не курится уж под ним
# кадильниц благовонный дым,
# не слышно пенье в поздний час
# молящих иноков за нас.
# теперь один старик седой,
# развалин страж полуживой,
# людьми и смертию забыт,
# сметает пыль с могильных плит,
# которых надпись говорит
# о славе прошлой — и о том,
# как, удручен своим венцом,
# такой-то царь, в такой-то год,
# вручал россии свой народ.
# и божья благодать сошла
# на грузию! она цвела
# с тех пор в тени своих садов,
# не опасаяся врагов,
# 3а гранью дружеских штыков.
#
# однажды русский генерал
# из гор к тифлису проезжал;
# ребенка пленного он вез.
# тот занемог, не перенес
# трудов далекого пути;
# он был, казалось, лет шести,
# как серна гор, пуглив и дик
# и слаб и гибок, как тростник.
# но в нем мучительный недуг
# ...

# %%
# 2) удаляем символы пунктуации и переноса строки
lower_no_n = re.sub(r'\n', ' ', lower_text) # заменяем перенос строки на пробел
lower_no_punkt = re.sub(r'[^\w\s]', '', lower_no_n) # удаляем пунктуацию
print(lower_no_punkt)
# Out:
#   немного лет тому назад там где сливаяся шумят обнявшись будто две сестры струи арагвы и куры был монастырь изза горы и нынче видит пешеход столбы обрушенных ворот и башни и церковный свод но не курится уж под ним кадильниц благовонный дым не слышно пенье в поздний час молящих иноков за нас теперь один старик седой развалин страж полуживой людьми и смертию забыт сметает пыль с могильных плит которых надпись говорит о славе прошлой  и о том как удручен своим венцом такойто царь в такойто год вручал россии свой народ и божья благодать сошла на грузию она цвела с тех пор в тени своих садов не опасаяся врагов 3а гранью дружеских штыков  однажды русский генерал из гор к тифлису проезжал ребенка пленного он вез тот занемог не перенес трудов далекого пути он был казалось лет шести как серна гор пуглив и дик и слаб и гибок как тростник но в нем мучительный недуг развил тогда могучий дух его отцов без жалоб он томился даже слабый стон из детских губ не вылетал он знаком пищу отвергал и тихо 
# ...

# %% [markdown]
# Задание 3: Токенизация
#
#
# 1. Выполните токенизацию нормализованного текста на слова. Сколько токенов в тексте? А сколько уникальных?
# 2. Выполните токенизацию изначального текста на строки при помощи split('\n'). Отобразите сколько их.
# 3. Напишите цикл, который пройдет по всем токенам текста и сохранит в новой переменной те, которые начинаются с заглавной буквы.
# 4. *Модернизируйте цикл так, чтобы он сохранял в переменную слова с заглавной буквы за исключением тех, которые являются первыми в строке.

# %%
#Пример для 3.3
words = ["Привет", "мир", "Python", "программирование", "Функция"] #Создаем лист со словами
for word in range(len(words)): #Цикл для листа слов
  if words[word][0].isupper(): #Проверяем, является ли заглавным [0] символ каждого слова
    print(words[word])
# Out:
# Привет
# Python
# Функция

# %%
# 1.1 наивная токенизация нормализованного текста
naive_tokens = lower_no_punkt.split()
print(naive_tokens)
print('Количество токенов', len(naive_tokens)) # количество токенов в тексте
print('Количество уникальных токенов', len(set(naive_tokens))) # количество уникальных токенов
# Out:
# ['немного', 'лет', 'тому', 'назад', 'там', 'где', 'сливаяся', 'шумят', 'обнявшись', 'будто', 'две', 'сестры', 'струи', 'арагвы', 'и', 'куры', 'был', 'монастырь', 'изза', 'горы', 'и', 'нынче', 'видит', 'пешеход', 'столбы', 'обрушенных', 'ворот', 'и', 'башни', 'и', 'церковный', 'свод', 'но', 'не', 'курится', 'уж', 'под', 'ним', 'кадильниц', 'благовонный', 'дым', 'не', 'слышно', 'пенье', 'в', 'поздний', 'час', 'молящих', 'иноков', 'за', 'нас', 'теперь', 'один', 'старик', 'седой', 'развалин', 'страж', 'полуживой', 'людьми', 'и', 'смертию', 'забыт', 'сметает', 'пыль', 'с', 'могильных', 'плит', 'которых', 'надпись', 'говорит', 'о', 'славе', 'прошлой', 'и', 'о', 'том', 'как', 'удручен', 'своим', 'венцом', 'такойто', 'царь', 'в', 'такойто', 'год', 'вручал', 'россии', 'свой', 'народ', 'и', 'божья', 'благодать', 'сошла', 'на', 'грузию', 'она', 'цвела', 'с', 'тех', 'пор', 'в', 'тени', 'своих', 'садов', 'не', 'опасаяся', 'врагов', '3а', 'гранью', 'дружеских', 'штыков', 'однажды', 'русский', 'ген
# ...

# %%
# 1.1 токенизация нормализованного текста через библиотеку nltk
import nltk # импортируем библиотеку
nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk import word_tokenize # импортируем из библиотеки функцию для токенизации

# %%
tokens = word_tokenize(lower_no_punkt) # токенизация нормализованного текста через библиотеку nltk
print(tokens)
print('Количество токенов', len(tokens))
print('Количество уникальных токенов', len(set(tokens)))
# Out:
# ['немного', 'лет', 'тому', 'назад', 'там', 'где', 'сливаяся', 'шумят', 'обнявшись', 'будто', 'две', 'сестры', 'струи', 'арагвы', 'и', 'куры', 'был', 'монастырь', 'изза', 'горы', 'и', 'нынче', 'видит', 'пешеход', 'столбы', 'обрушенных', 'ворот', 'и', 'башни', 'и', 'церковный', 'свод', 'но', 'не', 'курится', 'уж', 'под', 'ним', 'кадильниц', 'благовонный', 'дым', 'не', 'слышно', 'пенье', 'в', 'поздний', 'час', 'молящих', 'иноков', 'за', 'нас', 'теперь', 'один', 'старик', 'седой', 'развалин', 'страж', 'полуживой', 'людьми', 'и', 'смертию', 'забыт', 'сметает', 'пыль', 'с', 'могильных', 'плит', 'которых', 'надпись', 'говорит', 'о', 'славе', 'прошлой', 'и', 'о', 'том', 'как', 'удручен', 'своим', 'венцом', 'такойто', 'царь', 'в', 'такойто', 'год', 'вручал', 'россии', 'свой', 'народ', 'и', 'божья', 'благодать', 'сошла', 'на', 'грузию', 'она', 'цвела', 'с', 'тех', 'пор', 'в', 'тени', 'своих', 'садов', 'не', 'опасаяся', 'врагов', '3а', 'гранью', 'дружеских', 'штыков', 'однажды', 'русский', 'ген
# ...

# %%
# 2 токенизация изначального текста на строки при помощи split('\n'). Отобразите сколько их
tok_lines = text.split('\n')
print(tok_lines)
print('Количество токенов по переносу строки', len(tok_lines))
# Out:
# ['', '', 'Немного лет тому назад,', 'Там, где, сливаяся, шумят,', 'Обнявшись, будто две сестры,', 'Струи Арагвы и Куры,', 'Был монастырь. Из-за горы', 'И нынче видит пешеход', 'Столбы обрушенных ворот,', 'И башни, и церковный свод;', 'Но не курится уж под ним', 'Кадильниц благовонный дым,', 'Не слышно пенье в поздний час', 'Молящих иноков за нас.', 'Теперь один старик седой,', 'Развалин страж полуживой,', 'Людьми и смертию забыт,', 'Сметает пыль с могильных плит,', 'Которых надпись говорит', 'О славе прошлой — и о том,', 'Как, удручен своим венцом,', 'Такой-то царь, в такой-то год,', 'Вручал России свой народ.', 'И божья благодать сошла', 'На Грузию! Она цвела', 'С тех пор в тени своих садов,', 'Не опасаяся врагов,', '3а гранью дружеских штыков.', '', 'Однажды русский генерал', 'Из гор к Тифлису проезжал;', 'Ребенка пленного он вез.', 'Тот занемог, не перенес', 'Трудов далекого пути;', 'Он был, казалось, лет шести,', 'Как серна гор, пуглив и дик', 'И слаб и гибок, как тростник.', 'Но
# ...

# %%
# 3) соберём все токены с заглавной буквы
toks = word_tokenize(text) # токенизируем текст библиотекой
print(toks)
print('Количество токенов в тексте', len(toks))
cap_toks = [] # создаем пустой список для токенов с заглавной буквы
for tok in range(len(toks)): # цикл для токенов
  if toks[tok][0].isupper(): # проверяем, является ли заглавным [0] символ каждого токена
    cap_toks.append(toks[tok]) # добавляем в список токенов с заглавной буквы
print(cap_toks)
print('Количество токенов с заглавной буквы', len(cap_toks))
# Out:
# ['Немного', 'лет', 'тому', 'назад', ',', 'Там', ',', 'где', ',', 'сливаяся', ',', 'шумят', ',', 'Обнявшись', ',', 'будто', 'две', 'сестры', ',', 'Струи', 'Арагвы', 'и', 'Куры', ',', 'Был', 'монастырь', '.', 'Из-за', 'горы', 'И', 'нынче', 'видит', 'пешеход', 'Столбы', 'обрушенных', 'ворот', ',', 'И', 'башни', ',', 'и', 'церковный', 'свод', ';', 'Но', 'не', 'курится', 'уж', 'под', 'ним', 'Кадильниц', 'благовонный', 'дым', ',', 'Не', 'слышно', 'пенье', 'в', 'поздний', 'час', 'Молящих', 'иноков', 'за', 'нас', '.', 'Теперь', 'один', 'старик', 'седой', ',', 'Развалин', 'страж', 'полуживой', ',', 'Людьми', 'и', 'смертию', 'забыт', ',', 'Сметает', 'пыль', 'с', 'могильных', 'плит', ',', 'Которых', 'надпись', 'говорит', 'О', 'славе', 'прошлой', '—', 'и', 'о', 'том', ',', 'Как', ',', 'удручен', 'своим', 'венцом', ',', 'Такой-то', 'царь', ',', 'в', 'такой-то', 'год', ',', 'Вручал', 'России', 'свой', 'народ', '.', 'И', 'божья', 'благодать', 'сошла', 'На', 'Грузию', '!', 'Она', 'цвела', 'С', 'тех'
# ...

# %%
# 3* Модернизируйте цикл так, чтобы он сохранял в переменную слова с заглавной буквы за исключением тех, которые являются первыми в строке
# подозреваю, что это неправильное решение

tok_lines = text.split('\n') # токенизируем на строки
new = [] # создаем пустой список
for element in tok_lines: # цикл для отрезания первой буквы каждой строки
  new.append(element[1:])
cap_toks = [] # создаем пустой список для токенов с заглавной буквы
for i in range(len(new)): # цикл по количеству элементов в списке new
  for el in new[i].split(): # проходимся по элементам списка new и разбиваем их на токены-слова
    if el[0].isupper(): # проверяем, является ли заглавным [0] символ каждого токена-слова
      cap_toks.append(el) # добавляем в список токенов с заглавной буквы
print(cap_toks)
print('Количество токенов с заглавной буквы', len(cap_toks))
# Out:
# ['Арагвы', 'Куры,', 'Из-за', 'России', 'Грузию!', 'Она', 'Тифлису', 'Без', 'Темный']
# Количество токенов с заглавной буквы 9

# %% [markdown]
# Задание 4: Удаление стоп слов
#
#
# 1. Импортируйте список стоп-слов для русского языка из NLTK.
# 2. Напишите цикл, который пройдет по всем токенам и вернет новый список токенов без стоп-слов.
# 3. Сколько слов осталось в тексте? А уникальных?
# 4. *При помощи регулярного выражения найдите все слова с сочетанием букв 'бол' (с опциональной о) внутри слова. Добавьте их к стоп-словам и удалите из текста. Сколько осталось слов в тексте?

# %%
from nltk.corpus import stopwords # импортируем модуль stopwords из nltk

# %%
# 1) импортируем список стоп-слов для русского языка в nltk
nltk_stopwords_ru = stopwords.words('russian')
print(nltk_stopwords_ru) # посмотрим на него
# Out:
# ['и', 'в', 'во', 'не', 'что', 'он', 'на', 'я', 'с', 'со', 'как', 'а', 'то', 'все', 'она', 'так', 'его', 'но', 'да', 'ты', 'к', 'у', 'же', 'вы', 'за', 'бы', 'по', 'только', 'ее', 'мне', 'было', 'вот', 'от', 'меня', 'еще', 'нет', 'о', 'из', 'ему', 'теперь', 'когда', 'даже', 'ну', 'вдруг', 'ли', 'если', 'уже', 'или', 'ни', 'быть', 'был', 'него', 'до', 'вас', 'нибудь', 'опять', 'уж', 'вам', 'ведь', 'там', 'потом', 'себя', 'ничего', 'ей', 'может', 'они', 'тут', 'где', 'есть', 'надо', 'ней', 'для', 'мы', 'тебя', 'их', 'чем', 'была', 'сам', 'чтоб', 'без', 'будто', 'чего', 'раз', 'тоже', 'себе', 'под', 'будет', 'ж', 'тогда', 'кто', 'этот', 'того', 'потому', 'этого', 'какой', 'совсем', 'ним', 'здесь', 'этом', 'один', 'почти', 'мой', 'тем', 'чтобы', 'нее', 'сейчас', 'были', 'куда', 'зачем', 'всех', 'никогда', 'можно', 'при', 'наконец', 'два', 'об', 'другой', 'хоть', 'после', 'над', 'больше', 'тот', 'через', 'эти', 'нас', 'про', 'всего', 'них', 'какая', 'много', 'разве', 'три', 'эту', 'моя', 'в
# ...

# %%
# 2) циклом for соберём токены, которые не являются стоп-словами
tokens_no_stop_words = []
for token in word_tokenize(text.lower()):
    if token not in nltk_stopwords_ru:
        tokens_no_stop_words.append(token)
print(tokens_no_stop_words)
# Out:
# ['немного', 'лет', 'тому', 'назад', ',', ',', ',', 'сливаяся', ',', 'шумят', ',', 'обнявшись', ',', 'две', 'сестры', ',', 'струи', 'арагвы', 'куры', ',', 'монастырь', '.', 'из-за', 'горы', 'нынче', 'видит', 'пешеход', 'столбы', 'обрушенных', 'ворот', ',', 'башни', ',', 'церковный', 'свод', ';', 'курится', 'кадильниц', 'благовонный', 'дым', ',', 'слышно', 'пенье', 'поздний', 'час', 'молящих', 'иноков', '.', 'старик', 'седой', ',', 'развалин', 'страж', 'полуживой', ',', 'людьми', 'смертию', 'забыт', ',', 'сметает', 'пыль', 'могильных', 'плит', ',', 'которых', 'надпись', 'говорит', 'славе', 'прошлой', '—', ',', ',', 'удручен', 'своим', 'венцом', ',', 'такой-то', 'царь', ',', 'такой-то', 'год', ',', 'вручал', 'россии', 'свой', 'народ', '.', 'божья', 'благодать', 'сошла', 'грузию', '!', 'цвела', 'тех', 'пор', 'тени', 'своих', 'садов', ',', 'опасаяся', 'врагов', ',', '3а', 'гранью', 'дружеских', 'штыков', '.', 'однажды', 'русский', 'генерал', 'гор', 'тифлису', 'проезжал', ';', 'ребенка', '
# ...

# %%
print('Количество токенов без стоп-слов', len(tokens_no_stop_words))
print('Количество уникальных токенов без стоп-слов', len(set(tokens_no_stop_words)))
# Out:
# Количество токенов без стоп-слов 295
# Количество уникальных токенов без стоп-слов 216

# %%
# 4* При помощи регулярного выражения найдите все слова с сочетанием букв 'бол' (с опциональной о) внутри слова.
# не понятно задание – нет таких слов, чтобы сочетание этих букв было именно внутри слова
add = re.findall(r'\w+б[а-я]?л\w*', text) # ищем слова с сочетанием 'бол' (с опциональной о) внутри слова
print(add)
stops = nltk_stopwords_ru + add # добавляем эти слова к списку стоп-слов из библиотеки
tokens_no_stop_words = []
for token in word_tokenize(text.lower()):
    if token not in stops:
        tokens_no_stop_words.append(token)
print(tokens_no_stop_words)
print('Количество токенов без стоп-слов', len(tokens_no_stop_words))
# Out:
# []
# ...

# %%
# 4* чтобы посмотреть, что разница есть
add = re.findall(r'\w*б[а-я]?л\w*', text) # ищем слова с сочетанием 'бол' (с опциональной о = любая другая буква, которой может и не быть) в любом месте слова
print(add)
stops = nltk_stopwords_ru + add # добавляем эти слова к списку стоп-слов из библиотеки
tokens_no_stop_words = []
for token in word_tokenize(text.lower()):
    if token not in stops:
        tokens_no_stop_words.append(token)
print(tokens_no_stop_words)
print('Количество токенов без стоп-слов', len(tokens_no_stop_words))
# Out:
# ['благовонный', 'благодать', 'был', 'были', 'бледен', 'был', 'близок', 'больной']
# ...
